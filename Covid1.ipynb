# %% [markdown]
# #Covid 19 Analysis Notebook

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Importing covid19 dataset

# %%
corona_dataset_csv = pd.read_csv('/content/drive/My Drive/Callobatory/time_series_covid19_confirmed_global.csv')

corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  6/22/20  6/23/20
# 0                           NaN          Afghanistan  ...    29157    29481
# 1                           NaN              Albania  ...     1995     2047
# 2                           NaN              Algeria  ...    11920    12076
# 3                           NaN              Andorra  ...      855      855
# 4                           NaN               Angola  ...      186      189
# 5                           NaN  Antigua and Barbuda  ...       26       26
# 6                           NaN            Argentina  ...    44931    47203
# 7                           NaN              Armenia  ...    20588    21006
# 8  Australian Capital Territory            Australia  ...      108      108
# 9               New South Wales            Australia  ...     3150     3159
#
# [10 rows x 158 columns]

# %%
corona_dataset_csv.shape
# Out:
# (266, 158)

# %% [markdown]
# # Cleaning up the data

# %%
corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  6/22/20  6/23/20
# 0                           NaN          Afghanistan  ...    29157    29481
# 1                           NaN              Albania  ...     1995     2047
# 2                           NaN              Algeria  ...    11920    12076
# 3                           NaN              Andorra  ...      855      855
# 4                           NaN               Angola  ...      186      189
# 5                           NaN  Antigua and Barbuda  ...       26       26
# 6                           NaN            Argentina  ...    44931    47203
# 7                           NaN              Armenia  ...    20588    21006
# 8  Australian Capital Territory            Australia  ...      108      108
# 9               New South Wales            Australia  ...     3150     3159
#
# [10 rows x 156 columns]

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  6/21/20  6/22/20  6/23/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...    28833    29157    29481
# Albania               0        0        0  ...     1962     1995     2047
# Algeria               0        0        0  ...    11771    11920    12076
# Andorra               0        0        0  ...      855      855      855
# Angola                0        0        0  ...      183      186      189
#
# [5 rows x 154 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (188, 154)

# %% [markdown]
# #Visualizing Data by country

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
plt.legend()

# %% [markdown]
# #First derivative of the curve

# %%
corona_dataset_aggregated.loc['China'].diff().plot()

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc['Italy'].diff().max()
# Out:
# 6557.0

# %% [markdown]
# #Creating max_infection_rate column

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  6/22/20  6/23/20  max infection rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...    29157    29481               915.0
# Albania               0        0        0  ...     1995     2047                82.0
# Algeria               0        0        0  ...    11920    12076               199.0
# Andorra               0        0        0  ...      855      855                79.0
# Angola                0        0        0  ...      186      189                17.0
#
# [5 rows x 155 columns]

# %% [markdown]
# #Final Dataset with only max_infection_rate

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  915.0
# Albania                       82.0
# Algeria                      199.0
# Andorra                       79.0
# Angola                        17.0

# %% [markdown]
# #Importing World Happiness Report Dataset

# %%
world_happiness_report = pd.read_csv("/content/drive/My Drive/Callobatory/worldhappinessreport_WHR20_DataForFigure2.1.csv")
world_happiness_report.head()
# Out:
#   Country name  ... Dystopia + residual
# 0      Finland  ...            2.762835
# 1      Denmark  ...            2.432741
# 2  Switzerland  ...            2.350267
# 3      Iceland  ...            2.460688
# 4       Norway  ...            2.168266
#
# [5 rows x 20 columns]

# %% [markdown]
# #Cleaning up the data

# %%
columns_to_keep = ['Country name','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices' ]
world_happiness_report = world_happiness_report[columns_to_keep]
world_happiness_report.head()
# Out:
#   Country name  ...  Freedom to make life choices
# 0      Finland  ...                      0.949172
# 1      Denmark  ...                      0.951444
# 2  Switzerland  ...                      0.921337
# 3      Iceland  ...                      0.948892
# 4       Norway  ...                      0.955750
#
# [5 rows x 5 columns]

# %% [markdown]
# #Changing the index

# %%
world_happiness_report.set_index(['Country name'],inplace=True)
world_happiness_report.head()
# Out:
#               Logged GDP per capita  ...  Freedom to make life choices
# Country name                         ...
# Finland                   10.639267  ...                      0.949172
# Denmark                   10.774001  ...                      0.951444
# Switzerland               10.979933  ...                      0.921337
# Iceland                   10.772559  ...                      0.948892
# Norway                    11.087804  ...                      0.955750
#
# [5 rows x 4 columns]

# %% [markdown]
# #Joining the Dataset

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#               Logged GDP per capita  ...  max infection rate
# Country name                         ...
# Finland                   10.639267  ...               267.0
# Denmark                   10.774001  ...               391.0
# Switzerland               10.979933  ...              1321.0
# Iceland                   10.772559  ...                99.0
# Norway                    11.087804  ...               386.0
#
# [5 rows x 5 columns]

# %% [markdown]
# #Correlation Matrix

# %%
data.corr()
# Out:
#                               Logged GDP per capita  ...  max infection rate
# Logged GDP per capita                      1.000000  ...            0.155670
# Social support                             0.781814  ...            0.121921
# Healthy life expectancy                    0.848469  ...            0.164148
# Freedom to make life choices               0.419019  ...            0.049160
# max infection rate                         0.155670  ...            1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# #Visualizing the data
# #Plotting GDP vs max infection rate

# %%
x = data['Logged GDP per capita']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# #Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# #Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# #Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
